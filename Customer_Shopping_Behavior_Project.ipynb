# %%
import pandas as pd
df = pd.read_csv('customer_shopping_behavior1.csv')

# %%
df.head()
# Out:
#    customer_id  age gender item_purchased  category  purchase_amount  \
# 0            1   55   Male         Blouse  Clothing               53
# 1            2   19   Male        Sweater  Clothing               64
# 2            3   50   Male          Jeans  Clothing               73
# 3            4   21   Male        Sandals  Footwear               90
# 4            5   45   Male         Blouse  Clothing               49
#
#         location size      color  season  review_rating subscription_status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
#    shipping_type discount_applied  previous_purchases payment_method  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   customer_id              3900 non-null   int64
#  1   age                      3900 non-null   int64
#  2   gender                   3900 non-null   object
#  3   item_purchased           3900 non-null   object
#  4   category                 3900 non-null   object
#  5   purchase_amount          3900 non-null   int64
#  6   location                 3900 non-null   object
#  7   size                     3900 non-null   object
#  8   color                    3900 non-null   object
#  9   season                   3900 non-null   object
#  10  review_rating            3900 non-null   float64
#  11  subscription_status      3900 non-null   object
#  12  shipping_type            3900 non-null   object
#  13  discount_applied         3900 non-null   object
# ...

# %%
df.describe(include='all')
# Out:
#         customer_id          age gender item_purchased  category  \
# count   3900.000000  3900.000000   3900           3900      3900
# unique          NaN          NaN      2             25         4
# top             NaN          NaN   Male         Blouse  Clothing
# freq            NaN          NaN   2652            171      1737
# mean    1950.500000    44.068462    NaN            NaN       NaN
# std     1125.977353    15.207589    NaN            NaN       NaN
# min        1.000000    18.000000    NaN            NaN       NaN
# 25%      975.750000    31.000000    NaN            NaN       NaN
# 50%     1950.500000    44.000000    NaN            NaN       NaN
# 75%     2925.250000    57.000000    NaN            NaN       NaN
# max     3900.000000    70.000000    NaN            NaN       NaN
#
#         purchase_amount location  size  color  season  review_rating  \
# count       3900.000000     3900  3900   3900    3900    3900.000000
# ...

# %%
df.isnull().sum()
# Out:
# customer_id                  0
# age                          0
# gender                       0
# item_purchased               0
# category                     0
# purchase_amount              0
# location                     0
# size                         0
# color                        0
# season                       0
# review_rating                0
# subscription_status          0
# shipping_type                0
# discount_applied             0
# previous_purchases           0
# payment_method               0
# frequency_of_purchases       0
# age_group                    0
# purchase_frequency_days    547
# dtype: int64

# %%
df['review_rating'] = df.groupby('category')['review_rating'].transform(lambda x: x.fillna(x.median()))

# %%
df.isnull().sum()
# Out:
# customer_id                  0
# age                          0
# gender                       0
# item_purchased               0
# category                     0
# purchase_amount              0
# location                     0
# size                         0
# color                        0
# season                       0
# review_rating                0
# subscription_status          0
# shipping_type                0
# discount_applied             0
# previous_purchases           0
# payment_method               0
# frequency_of_purchases       0
# age_group                    0
# purchase_frequency_days    547
# dtype: int64

# %%
df.columns = df.columns.str.lower()
df.columns = df.columns.str.replace(' ','_')
df=df.rename(columns={'purchase_amount_(usd)':'purchase_amount'})

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'previous_purchases', 'payment_method',
#        'frequency_of_purchases', 'age_group', 'purchase_frequency_days'],
#       dtype='object')

# %%
#Create a new column  age_group
labels=['Young Adults','Adults','Middle_aged','Senior']
df['age_group'] = pd.qcut(df['age'],q=4,labels=labels)

# %%
df[['age','age_group']].head(10)
# Out:
#    age     age_group
# 0   55   Middle_aged
# 1   19  Young Adults
# 2   50   Middle_aged
# 3   21  Young Adults
# 4   45   Middle_aged
# 5   46   Middle_aged
# 6   63        Senior
# 7   27  Young Adults
# 8   26  Young Adults
# 9   57   Middle_aged

# %%
# Perchase purchase_frequency_days
frequency_mapping={
    'Fortnightly':14,
    'Weekly':7,
    'Monthly':30,
    'Quarterly':90,
    'Bi_weekly':14,
    'Annually':365,
    'Every 3 Months':90
}
df['purchase_frequency_days']=df['frequency_of_purchases'].map(frequency_mapping)

# %%
df[['purchase_frequency_days','frequency_of_purchases']].head(10)
# Out:
#    purchase_frequency_days frequency_of_purchases
# 0                     14.0            Fortnightly
# 1                     14.0            Fortnightly
# 2                      7.0                 Weekly
# 3                      7.0                 Weekly
# 4                    365.0               Annually
# 5                      7.0                 Weekly
# 6                     90.0              Quarterly
# 7                      7.0                 Weekly
# 8                    365.0               Annually
# 9                     90.0              Quarterly

# %%
  # or however you want to populate it
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 df['promo_code_used'] = Yes
#
# NameError: name 'Yes' is not defined

# %%
df[['discount_applied','promo_code_used']].head(10)
# Out:
#   discount_applied promo_code_used
# 0              Yes            None
# 1              Yes            None
# 2              Yes            None
# 3              Yes            None
# 4              Yes            None
# 5              Yes            None
# 6              Yes            None
# 7              Yes            None
# 8              Yes            None
# 9              Yes            None

# %%
(df['discount_applied']==df['promo_code_used']).all()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\panda1\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'promo_code_used'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 (df['discount_applied']==df['promo_code_used']).all()
#
# ...

# %%
df=df.drop('promo_code_used',axis=1)

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'previous_purchases', 'payment_method',
#        'frequency_of_purchases', 'age_group', 'purchase_frequency_days'],
#       dtype='object')

# %%
df.to_csv("customer_shopping_behavior1.csv",index=False)

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\Admin

# %%
df.to_csv(r"C:\Users\Admin\customer_shopping_behavior1.csv",index=False)

# %%
cheack=pd.read_csv("customer_shopping_behavior1.csv")
cheack.head()
# Out:
#    customer_id  age gender item_purchased  category  purchase_amount  \
# 0            1   55   Male         Blouse  Clothing               53
# 1            2   19   Male        Sweater  Clothing               64
# 2            3   50   Male          Jeans  Clothing               73
# 3            4   21   Male        Sandals  Footwear               90
# 4            5   45   Male         Blouse  Clothing               49
#
#         location size      color  season  review_rating subscription_status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
#    shipping_type discount_applied  previous_purchases payment_method  \
# ...

# %%
pip install psycopg2.binary sqlalchemy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install mysql-connector-python SQLAlchemy pymysql

# %%
import mysql.connector

conn = mysql.connector.connect(
    host='DESKTOP-B7HVS6K',
    user='root',
    password='Sunil@123',
    port=3306
)

cursor = conn.cursor()

# %%
import mysql.connector

# Connect to MySQL
connection = mysql.connector.connect(
    host='DESKTOP-B7HVS6K',
    user='root',
    password='Sunil@123',
    database='Project1',  # 👈 replace with your DB name
    port=3306
)

# Create a cursor and test the connection
cursor = connection.cursor()
cursor.execute("SELECT DATABASE();")
print("Connected to database:", cursor.fetchone())

cursor.close()
connection.close()
# Out:
# Connected to database: ('project1',)

# %%
cursor.execute("SHOW DATABASES;")

for db in cursor:
    print(db)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# File ~\panda1\Lib\site-packages\mysql\connector\cursor_cext.py:311, in CMySQLCursor.execute(self, operation, params, map_results)
#     310     if not self._connection or self._connection.is_closed():
# --> 311         raise ProgrammingError
#     312 except (ProgrammingError, ReferenceError) as err:
#
# ProgrammingError: Unknown error
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 cursor.execute("SHOW DATABASES;")
#       3 for db in cursor:
#       4     print(db)
#
# File ~\panda1\Lib\site-packages\mysql\connector\cursor_cext.py:313, in CMySQLCursor.execute(self, operation, params, map_results)
#     311         raise ProgrammingError
# ...

# %%
# Step 1: Import required libraries
import pandas as pd
from sqlalchemy import create_engine

# %%
df = pd.read_csv('customer_shopping_behavior1.csv')
df.head(10)
# Out:
#    customer_id  age gender item_purchased     category  purchase_amount  \
# 0            1   55   Male         Blouse     Clothing               53
# 1            2   19   Male        Sweater     Clothing               64
# 2            3   50   Male          Jeans     Clothing               73
# 3            4   21   Male        Sandals     Footwear               90
# 4            5   45   Male         Blouse     Clothing               49
# 5            6   46   Male       Sneakers     Footwear               20
# 6            7   63   Male          Shirt     Clothing               85
# 7            8   27   Male         Shorts     Clothing               34
# 8            9   26   Male           Coat    Outerwear               97
# 9           10   57   Male        Handbag  Accessories               31
#
#         location size      color  season  review_rating subscription_status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# ...

# %%
# Step 1: Import required libraries
import pandas as pd
from sqlalchemy import create_engine

# %%
# Step 0: Import necessary module
from sqlalchemy import create_engine

# Step 1: Database credentials
host = 'DESKTOP-B7HVS6K'
user = 'root'
password = 'Sunil@123'
database = 'Project1'
port = 3306

# Step 2: Create SQLAlchemy connection engine
engine = create_engine(f"mysql+pymysql://{user}:{password}@{host}:{port}/{database}")

# Step 3: Test the connection
try:
    with engine.connect() as connection:
        result = connection.execute("SELECT DATABASE();")
        for row in result:
            print(f"Connected to database: {row[0]}")
except Exception as e:
    print(f"Connection failed: {e}")
# Out:
# Connection failed: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '123@DESKTOP-B7HVS6K' ([Errno 11003] getaddrinfo failed)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
import urllib.parse
from sqlalchemy import create_engine

# Database credentials
host = 'DESKTOP-B7HVS6K'
user = 'root'
password = urllib.parse.quote_plus('Sunil@123')  # <-- URL-encode
database = 'Project1'
port = 3306

# Create SQLAlchemy engine
engine = create_engine(f"mysql+pymysql://{user}:{password}@{host}:{port}/{database}")

# Test connection
try:
    with engine.connect() as connection:
        result = connection.execute("SELECT DATABASE();")
        for row in result:
            print(f"Connected to database: {row[0]}")
except Exception as e:
    print(f"Connection failed: {e}")
# Out:
# Connection failed: Not an executable object: 'SELECT DATABASE();'

# %%
from sqlalchemy import create_engine, text
import urllib.parse

# Database credentials
host = 'DESKTOP-B7HVS6K'
user = 'root'
password = urllib.parse.quote_plus('Sunil@123')  # URL-encode special characters
database = 'Project2'
port = 3306

# Create SQLAlchemy engine
engine = create_engine(f"mysql+pymysql://{user}:{password}@{host}:{port}/{database}")

# Test connection
try:
    with engine.connect() as connection:
        result = connection.execute(text("SELECT DATABASE();"))
        for row in result:
            print(f"Connected to database: {row[0]}")
except Exception as e:
    print(f"Connection failed: {e}")
# Out:
# Connected to database: project2

# %%
import pandas as pd
from sqlalchemy import create_engine, text
import urllib.parse

# Database credentials
host = 'DESKTOP-B7HVS6K'
user = 'root'
password = urllib.parse.quote_plus('Sunil@123')
database = 'Project2'
port = 3306

# Create engine
engine = create_engine(f"mysql+pymysql://{user}:{password}@{host}:{port}/{database}")

# Read your CSV
df = pd.read_csv("customer_shopping_behavior1.csv")  # <-- put your CSV file path here

# Write CSV to MySQL table (replace 'my_table' with your desired table name)
df.to_sql('my_table', con=engine, if_exists='replace', index=False)

print("CSV imported successfully!")
# Out:
# CSV imported successfully!
